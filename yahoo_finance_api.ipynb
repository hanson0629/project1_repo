# %%
import requests
from io import StringIO
import csv
import pandas as pd

# %% [markdown]
# # import data function

# %%
def import_data(ticker):
    stock_url = 'https://query1.finance.yahoo.com/v7/finance/download/{}?'
    params = {
        'range': '10y',
        'interval': '1d',
        'events': 'history',
        'includeAdjustedClose': 'true'
    }
    response = requests.get(stock_url.format(ticker), params=params)
    file = StringIO(response.text)
    reader = csv.reader(file)
    data = list(reader)

    return pd.DataFrame(data[1:],columns=data[0])

# %%
test = import_data('BTC-USD')
test.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
bitcoin_data = import_data('BTC-USD')
gold_data = import_data('GC=F')
sp_data = import_data('^GSPC')
crude_data = import_data('CL=F')

# %%
gold_data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2011-04-05  1437.900024  1457.599976  1430.300049  1451.800049
# 1  2011-04-06  1456.900024  1462.300049  1452.000000  1457.699951
# 2  2011-04-07  1459.699951  1462.500000  1453.900024  1458.500000
# 3  2011-04-08  1457.599976  1475.500000  1457.500000  1473.400024
# 4  2011-04-11  1476.000000  1476.000000  1459.699951  1467.400024
#
#      Adj Close Volume
# 0  1451.800049   2609
# 1  1457.699951    901
# 2  1458.500000    229
# 3  1473.400024   1407
# 4  1467.400024    378

# %%
bitcoin_data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
sp_data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2011-04-06  1335.939941  1339.380005  1331.089966  1335.540039
# 1  2011-04-07  1334.819946  1338.800049  1326.560059  1333.510010
# 2  2011-04-08  1336.160034  1339.459961  1322.939941  1328.170044
# 3  2011-04-11  1329.010010  1333.770020  1321.060059  1324.459961
# 4  2011-04-12  1321.959961  1321.959961  1309.510010  1314.160034
#
#      Adj Close      Volume
# 0  1335.540039  4223740000
# 1  1333.510010  4005600000
# 2  1328.170044  3582810000
# 3  1324.459961  3478970000
# 4  1314.160034  4275490000

# %%
tickers = 'BTC-USD'

# %%
stock_url = 'https://query1.finance.yahoo.com/v7/finance/download/BTC-USD?'

params = {
    'range': '10y',
    'interval': '1d',
    'events': 'history',
    'includeAdjustedClose': 'true'
}
response = requests.get(stock_url.format(tickers), params=params)

# %%
file = StringIO(response.text)
reader = csv.reader(file)
data = list(reader)

df = pd.DataFrame(data[1:],columns=data[0])
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100
